# %%
from google.colab import drive
drive.mount('/content/drive')

content = 'No matter what it takes\n中文也可以寫\nThe End\n'

print(content)
# Out:
# Mounted at /content/drive
# No matter what it takes
# 中文也可以寫
# The End

# %%
f = open('/content/file1.txt', mode = 'w')

content2 = 'No matter what it takes\n中文也可以寫\nThe End\n'

f.write(content2)
f.close()

# %%
lyrics_file =  open('/content/file1.txt', mode = 'r')

lyrics = lyrics_file.read()
# print char_count
char_count = len(lyrics)
print(char_count)
lyrics_file.close()
# Out:
# 39

# %%
b = []
for e in b:
    e = e.strip()
    print(e)
    b.append(e)

print(b)
# Out:
# []

# %%
try:
    print(n)
except Exception as e:
    print(e)
finally:
    print('一定會執行')
# Out:
# name 'n' is not defined
# 一定會執行
